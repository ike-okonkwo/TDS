# %%
import pandas as pd
from fredapi import Fred
 
# API Key
fred = Fred('98e662ff53bed59abc3f64fbfa0598e4 ')
## you should register for a FRED API Key on the FRED website

# %%
series = range(100, 200)

# %%
for data in series:
    try:
        print fred.search_by_release(data)
    except:
        pass
# Out:
#                            frequency frequency_short      id  \
# series id
# FLEXSC     Bi-Weekly, Beg. of Period              BW  FLEXSC
#
#                  last_updated  \
# series id
# FLEXSC    2015-04-16 19:06:01
#
#                                                        notes observation_end  \
# series id
# FLEXSC     Beginning of Period  Seasonal credit is availa...      2015-04-16
#
#           observation_start popularity realtime_end realtime_start  \
# series id
# FLEXSC           1992-01-09         30   2015-04-23     2015-04-23
#
#                seasonal_adjustment seasonal_adjustment_short  \
# series id
# FLEXSC     Not Seasonally Adjusted                       NSA
#
#                                                       title    units  \
# series id
# FLEXSC     Eighth District Flexible Rate on Seasonal Credit  Percent
#
#           units_short
# series id
# FLEXSC              %
#                   frequency frequency_short        id        last_updated  \
# ...
